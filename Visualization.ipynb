# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\tehre\Studiesss\Python\Pandas\Reading files in Pandas docs\Ice Cream Ratings.csv")
df
# Out:
#        Date  Flavor Rating  Texture Rating  Overall Rating
# 0  1/1/2022       0.223090        0.040220        0.600129
# 1  1/2/2022       0.635886        0.938476        0.106264
# 2  1/3/2022       0.442323        0.044154        0.598112
# 3  1/4/2022       0.389128        0.549676        0.489353
# 4  1/5/2022       0.386887        0.519439        0.988280
# 5  1/6/2022       0.877984        0.193588        0.832827
# 6  1/7/2022       0.140995        0.325110        0.105147

# %%
df = df.set_index('Date')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22132\833540315.py in ?()
# ----> 1 df = df.set_index('Date')
#       2 df
#
# ~\Downloads\anaconda\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['Date'] are in the columns"

# %%
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df.plot()  #by default line chart
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind = 'line', subplots = True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
df.plot(kind = 'line', title = 'Ice-cream Ratings')
# Out:
# <Axes: title={'center': 'Ice-cream Ratings'}, xlabel='Date'>

# %%
df.plot(kind = 'line', title = 'Ice-cream Ratings', xlabel = 'Daily Ratings', ylabel = 'Rating Values')
# Out:
# <Axes: title={'center': 'Ice-cream Ratings'}, xlabel='Daily Ratings', ylabel='Rating Values'>

# %%
df.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='Date'>

# %%
df['Flavor Rating'].plot(kind = 'bar', stacked = True) #for single parameter chart do like this
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.barh(stacked = True) #for horizontal barchart
# Out:
# <Axes: ylabel='Date'>

# %%
df.plot.scatter() #scatter plot won't run without x and y specification
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.plot.scatter()
#
# TypeError: PlotAccessor.scatter() missing 2 required positional arguments: 'x' and 'y'

# %%
df.plot.scatter(x = 'Texture Rating', y = 'Overall Rating')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df.plot.scatter(x = 'Texture Rating', y = 'Overall Rating', s = 500, c = 'Yellow') #s for size of dots and c for color
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df.plot.hist() #by default the bin size is 10 in histogram
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot() # box chart- lowest maker shows lowest value, box lowest part shows 25 percentile of data,middle 50, top 75, highest bar =100
# Out:
# <Axes: >

# %%
df.plot.area()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.area(figsize = (10,5)) #figure size change 10in long, 5in high
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.pie() # have to specify which parameter to draw
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.plot.pie()
#
# File ~\Downloads\anaconda\Lib\site-packages\pandas\plotting\_core.py:1657, in PlotAccessor.pie(self, **kwargs)
#    1606 """
#    1607 Generate a pie plot.
#    1608
#    (...)
#    1650     >>> plot = df.plot.pie(subplots=True, figsize=(11, 6))
#    1651 """
#    1652 if (
#    1653     isinstance(self._parent, ABCDataFrame)
#    1654     and kwargs.get("y", None) is None
#    1655     and not kwargs.get("subplots", False)
#    1656 ):
# -> 1657     raise ValueError("pie requires either y column or 'subplots=True'")
#    1658 return self(kind="pie", **kwargs)
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
df.plot.pie(y='Flavor Rating')
# Out:
# <Axes: ylabel='Flavor Rating'>

# %%
df.plot.pie(y='Flavor Rating',figsize=(8,6))
# Out:
# <Axes: ylabel='Flavor Rating'>

# %%
print(plt.style.available) # these are different cghart styles we can select
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('classic')
df.plot()
# Out:
# <Axes: xlabel='Date'>
